# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setup and File Loading

import pandas as pd

FILE_PATH = '/content/drive/MyDrive/AI351ProjectTest/04-DataAugmentation/downsampled.csv'

# Read the Excel file into a DataFrame, selecting only the required columns
try:
    df = pd.read_csv(FILE_PATH)

    print(f"DataFrame loaded successfully with {len(df)} rows.")
    print(f"\nFirst 5 rows:")
    display(df.head())

except FileNotFoundError:
    print(f"ERROR: File not found at the specified path: {FILE_PATH}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# DataFrame loaded successfully with 23762 rows.
#
# First 5 rows:
#                                                 text  label label_desc  \
# 0  Normally I hate even thinking about this becau...      0    sadness
# 1  You are not alone, trust me. We all face our h...      0    sadness
# 2  i felt like talking too but i didn t know what...      0    sadness
# 3  My brother is like my best friend. We are clos...      0    sadness
# 4  i feel like nobody really care if i m gone eve...      0    sadness
#
#                                          translation  MetricX24_Raw  \
# 0  Karaniwan akong ayaw mag-isip tungkol dito dah...       0.180561
# 1  Hindi ka nag-iisa, maniwala ka sa akin. Lahat ...       0.221019
# 2  Gusto kong magsalita rin pero hindi ko alam ku...       0.923421
# 3  Ang kapatid ko ay parang pinakamahusay kong ka...      -0.688570
# 4  Nararamdaman kong walang tunay na nag-aalala k...       1.094810
#
#    MetricX24_Scaled_BATAYAN
# 0                 99.277754
# 1                 99.115925
# 2                 96.306317
# 3                100.000000
# 4                 95.620761

# %%
class_counts = df["label"].value_counts().sort_index()
print("Class distribution in df:")
display(class_counts)
# Out:
# Class distribution in df:
# label
# 0    6000
# 1    5362
# 2    1304
# 3    2159
# 4    2509
# 5    3841
# 6    2587
# Name: count, dtype: int64

# %%
# Define desired sample sizes per class label (0–6)
m = {
    0: 200,   # Sadness
    1: 200,   # Joy
    2: 200,   # Love
    3: 200,   # Anger
    4: 200,   # Fear
    5: 200,   # Anxiety
    6: 200    # Stress
}

print("Sampling sizes per class:")
for k, v in m.items():
    print(f"Class {k}: {v} samples")
# Out:
# Sampling sizes per class:
# Class 0: 200 samples
# Class 1: 200 samples
# Class 2: 200 samples
# Class 3: 200 samples
# Class 4: 200 samples
# Class 5: 200 samples
# Class 6: 200 samples

# %%
import numpy as np

df_subsamples = {}

for label in range(7):

    df_class = df[df["label"] == label]

    if label not in df["label"].unique():
        print(f"Class {label} not in dataset.")
        continue

    sample_size = m[label]

    if sample_size > len(df_class):
        print(f"WARNING: Class {label}: requested {sample_size}, only {len(df_class)} available.")
        sample_size = len(df_class)

    # Random Seed

    seed = 466

    df_sub = df_class.sample(sample_size, random_state=seed)
    df_subsamples[label] = df_sub
    print(f"Class {label}: Subsampled {sample_size} rows.")
# Out:
# Class 0: Subsampled 200 rows.
# Class 1: Subsampled 200 rows.
# Class 2: Subsampled 200 rows.
# Class 3: Subsampled 200 rows.
# Class 4: Subsampled 200 rows.
# Class 5: Subsampled 200 rows.
# Class 6: Subsampled 200 rows.

# %%
# !nvidia-smi
# !pip install transformers accelerate sentencepiece --quiet

from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "aisingapore/Gemma-SEA-LION-v3-9B-IT"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    dtype=torch.float16
)

print("SLM loaded successfully.")
# Out:
# Mon Dec  8 03:21:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             48W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/870 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.57G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# SLM loaded successfully.

# %%
# Erroneous Spellings Prompt Function

def build_prompt(text):
    return (
        # Persona (Do not Remove)
        "You are a synthetic data generator specializing in natural human error patterns found in Filipino social media posts. "

        # Indicate what kind of Data Augmentation they will do
        "Transform the Filipino sentence by adding realistic typo-like spelling errors, letter swaps, repeated letters, missing letters, or phonetic misspellings commonly found in casual posts. "

        # Additional rules
        "Keep the sentence understandable. Do NOT distort meaning. Do NOT introduce offensive content. Do not apply to all words and do not overdo it. "

        # One-Shot Example
        "Example: 'Huwag kang umalis.' becomes: 'Hwag kng umals.' "

        # Prompt to minimize information loss (Do not Remove)
        "Preserve the original meaning and emotional tone, even with typos. "

        # Prompt to only output the needed data (Do not Remove)
        "Do NOT provide commentary or explanations. Output only the revised sentence.\n\n"

        f"Text: {text}\n"
        "Augmented:"
    )

# %%
def augment_batch(text_list, batch_size=64):
    augmented = []

    for i in range(0, len(text_list), batch_size):
        batch = text_list[i:i + batch_size]

        prompts = [build_prompt(t) for t in batch]
        inputs = tokenizer(prompts, return_tensors="pt", padding=True, truncation=True).to(model.device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=120,
                do_sample=True,
                temperature=0.7,
                top_p=0.9
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # extract SLM output
        clean = []
        for txt in decoded:
            if "Augmented:" in txt:
                txt = txt.split("Augmented:")[-1].strip()
            clean.append(txt)

        augmented.extend(clean)

    return augmented

# %%
all_augmented = []

batch_size = 64

for label, df_sub in df_subsamples.items():
    print(f"\n=== Processing subsample {label} ===")

    tagalog_list = df_sub["translation"].tolist()
    total = len(tagalog_list)

    augmented = []
    next_progress = 5

    for i in range(0, total, batch_size):
        batch = tagalog_list[i:i + batch_size]
        batch_aug = augment_batch(batch, batch_size=batch_size)
        augmented.extend(batch_aug)

        percent = ((i + len(batch)) / total) * 100
        if percent >= next_progress:
            print(f"Subsample {label}: {next_progress}% complete")
            next_progress += 5

    df_aug = df_sub.copy()
    df_aug["translation"] = augmented   # overwrite

    all_augmented.append(df_aug)

print("\nAll subsamples processed successfully.")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# === Processing subsample 0 ===
# Subsample 0: 5% complete
# Subsample 0: 10% complete
# Subsample 0: 15% complete
# Subsample 0: 20% complete
#
# === Processing subsample 1 ===
# Subsample 1: 5% complete
# Subsample 1: 10% complete
# Subsample 1: 15% complete
# Subsample 1: 20% complete
#
# === Processing subsample 2 ===
# Subsample 2: 5% complete
# Subsample 2: 10% complete
# Subsample 2: 15% complete
# Subsample 2: 20% complete
#
# === Processing subsample 3 ===
# Subsample 3: 5% complete
# Subsample 3: 10% complete
# Subsample 3: 15% complete
# Subsample 3: 20% complete
#
# === Processing subsample 4 ===
# Subsample 4: 5% complete
# Subsample 4: 10% complete
# Subsample 4: 15% complete
# Subsample 4: 20% complete
#
# === Processing subsample 5 ===
# Subsample 5: 5% complete
# Subsample 5: 10% complete
# Subsample 5: 15% complete
# Subsample 5: 20% complete
#
# === Processing subsample 6 ===
# Subsample 6: 5% complete
# Subsample 6: 10% complete
# Subsample 6: 15% complete
# Subsample 6: 20% complete
#
# All subsamples processed successfully.

# %%
df_final = pd.concat(all_augmented, ignore_index=True)

print("Final dataset size:", len(df_final))
df_final.head()
# Out:
# Final dataset size: 1400
#                                                 text  label label_desc  \
# 0  Is anyone else trying to rebound? I am thinkin...      0    sadness
# 1  I am sick of living like this. I just want the...      0    sadness
# 2  so yesterday i had plan to go skating with a f...      0    sadness
# 3  I will never be good at something. Why?Because...      0    sadness
# 4  nothing is good anymore I just exist. I'm 16, ...      0    sadness
#
#                                          translation  MetricX24_Raw  \
# 0  Mayroon bng iba na nagtatangka rin mag-rebound...       0.870451
# 1  Napagod na ako sa ganitong pamumuhay. Gusto ko...       1.304011
# 2  Kahapon, plano kong mag-sk8 kasama ang isang k...       1.145098
# 3  Hindi ako magiging magaling sa kahit ano. Bkit...       1.236935
# 4  Walng mbuti na nangyayri na ngayon, umiiral ln...       0.277736
#
#    MetricX24_Scaled_BATAYAN
# 0                 96.518198
# 1                 94.783957
# 2                 95.419608
# 3                 95.052258
# 4                 98.889055

# %%
OUTPUT_PATH = "/content/drive/MyDrive/AI351ProjectTest/04-DataAugmentation/Augmentation05.csv"

df_final.to_csv(OUTPUT_PATH, index=False)

print("Saved final augmented dataset to:")
print(OUTPUT_PATH)
# Out:
# Saved final augmented dataset to:
# /content/drive/MyDrive/AI351ProjectTest/04-DataAugmentation/Augmentation05.csv

# %%
df_aug.head()
# Out:
#                                                     text  label label_desc  \
# 19028  I had no more than three consecutive appointme...      6     stress
# 22519  Post grad application and butter fingers I app...      6     stress
# 19544  **I don't want to be anxious in drawing class....      6     stress
# 18289  Do I just need to forget about the "dumb girlf...      6     stress
# 21913  Got important interview but so stressed due to...      6     stress
#
#                                              translation  MetricX24_Raw  \
# 19028  Nagkaroon ako ng hindi hihigit sa tatlo sunod-...      -0.814768
# 22519  Nag-aply ako ng post-grad sa isang programa na...       0.281999
# 19544  **Ayaw ko mng maging kinakabahan sa klase ng p...      -0.790826
# 18289  Kailngan ko bang klmutan na lng ang "bobo girl...      -0.823052
# 21913  May mahalagang panayam ngayon pero sobrang str...       0.293781
#
#        MetricX24_Scaled_BATAYAN
# 19028                100.000000
# 22519                 98.872003
# 19544                100.000000
# 18289                100.000000
# 21913                 98.824876
